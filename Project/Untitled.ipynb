# %%
def calculate_formula(mass, tolerance):
    # Define atomic masses (example values)
    atomic_masses = {'C': 12.01, 'H': 1.008, 'O': 16.00, 'N': 14.01}

    # Define constraints and bounds for elemental ratios
    min_ratio = {'C': 0.2, 'H': 0.2, 'O': 0.0, 'N':0.0}
    max_ratio = {'C': 0.9, 'H': 2.0, 'O': 1.0, 'N':0.5}

    possible_formulas = []

    for num_C in range(1, int((mass + tolerance) / atomic_masses['C']) + 1):
        for num_H in range(1, int((mass + tolerance) / atomic_masses['H']) + 1):
            for num_O in range(int((mass + tolerance) / atomic_masses['O']) + 1):
                for num_N in range(int((mass + tolerance) / atomic_masses['N']) + 1):
                    total_mass = num_C * atomic_masses['C'] + num_H * atomic_masses['H'] + num_O * atomic_masses['O'] + num_N * atomic_masses['N']    
                    if abs(total_mass - mass) <= tolerance:
                        # Check elemental ratios
                        total_atoms = num_C + num_H + num_O + num_N
                        ratio_C = num_C / total_atoms
                        ratio_H = num_H / total_atoms
                        ratio_O = num_O / total_atoms
                        ratio_N = num_N / total_atoms
                        if (min_ratio['C'] <= ratio_C <= max_ratio['C'] and
                            min_ratio['H'] <= ratio_H <= max_ratio['H'] and
                            min_ratio['O'] <= ratio_O <= max_ratio['O'] and
                            min_ratio['N'] <= ratio_N <= max_ratio['N']):
                            possible_formulas.append(f'C{num_C}H{num_H}O{num_O}N{num_N}')  # Format the formula string
    
    return possible_formulas

def refine_formulas(possible_formulas, mass_spectrum):
    refined_formulas = []
    
    for formula in possible_formulas:
        # Dummy refinement based on observed peaks within the formula's mass range
        # Replace this with actual refinement logic based on isotopic distribution and chemical rules
        
        # Calculate the sum of intensities of peaks within the formula's mass range
        observed_intensity = sum([mass_spectrum[mass] for mass in mass_spectrum if formula in mass_spectrum])
        
        # Apply additional constraints or rules to filter out unlikely formulas
        if observed_intensity > 0:
            refined_formulas.append(formula)
    
    return refined_formulas

# %%
from collections import Counter

# Sample mass spectrum data (mass: intensity)
mass_spectrum = {
    100: 50,   # Peak corresponding to a compound with molecular weight 100
    101: 100,  # Isotopic peak or another compound with molecular weight 101
    102: 80,   # Peak corresponding to a compound with molecular weight 102
    # Add more peaks as needed
}  # Add more peaks as needed

# Find the molecular ion peak (the highest intensity peak)
molecular_ion_mass = max(mass_spectrum, key=mass_spectrum.get)

# Calculate possible molecular formulas within a tolerance
tolerance = 0.1
possible_formulas = []

# Dummy list of possible formulas, replace this with actual formula generation
# For simplicity, let's assume we have a function `calculate_formula(mass)` that returns possible formulas
possible_formulas = calculate_formula(molecular_ion_mass, tolerance)

# Refine the list of formulas based on isotopic distribution
refined_formulas = []

# Dummy refinement process, replace this with actual refinement
# For simplicity, let's assume we have a function `refine_formulas(possible_formulas, mass_spectrum)` that refines the formulas
refined_formulas = refine_formulas(possible_formulas, mass_spectrum)

# Output the refined formulas
print("Possible Molecular Formulas:")
for formula in refined_formulas:
    print(formula)
# Out:
# Possible Molecular Formulas:

# %%
def calculate_formula(mass, tolerance):
    # Simple formula generation based on mass and tolerance
    possible_formulas = []
    for num_C in range(int((mass + tolerance) / 12) + 1):
        for num_H in range(int((mass + tolerance) / 1) + 1):
            for num_O in range(int((mass + tolerance) / 16) + 1):
                total_mass = num_C * 12 + num_H * 1 + num_O * 16
                if abs(total_mass - mass) <= tolerance:
                    formula = f'C{num_C}H{num_H}O{num_O}'
                    print("Generated Formula:", formula, "Total Mass:", total_mass)
                    possible_formulas.append(formula)
    return possible_formulas

def refine_formulas(possible_formulas, mass_spectrum):
    # Simple refinement based on observed peaks
    refined_formulas = []
    for formula in possible_formulas:
        # Extract atomic counts from the formula
        num_C = int(formula.split('C')[1].split('H')[0].split('O')[0])
        num_H = int(formula.split('H')[1].split('O')[0])
        num_O = int(formula.split('O')[1])
        
        # Calculate total mass of the formula
        total_mass = num_C * 12 + num_H * 1 + num_O * 16
        
        # Check if any mass in the formula is present in the mass spectrum
        if total_mass in mass_spectrum:
            refined_formulas.append(formula)
    return refined_formulas

# Example mass spectrum data (mass: intensity)
mass_spectrum = {
    100: 50,   # Peak corresponding to a compound with molecular weight 100
    101: 100,  # Isotopic peak or another compound with molecular weight 101
    102: 80,   # Peak corresponding to a compound with molecular weight 102
}

# Calculate possible formulas
possible_formulas = calculate_formula(100, 5)
print("Possible Formulas After Calculation:", possible_formulas)

# Refine formulas based on observed peaks
refined_formulas = refine_formulas(possible_formulas, mass_spectrum)

print("Refined Formulas After Refinement:")
for formula in refined_formulas:
    print(formula)
# Out:
# Generated Formula: C0H0O6 Total Mass: 96
# Generated Formula: C0H1O6 Total Mass: 97
# Generated Formula: C0H2O6 Total Mass: 98
# Generated Formula: C0H3O6 Total Mass: 99
# Generated Formula: C0H4O6 Total Mass: 100
# Generated Formula: C0H5O6 Total Mass: 101
# Generated Formula: C0H6O6 Total Mass: 102
# Generated Formula: C0H7O6 Total Mass: 103
# Generated Formula: C0H8O6 Total Mass: 104
# Generated Formula: C0H9O6 Total Mass: 105
# Generated Formula: C0H15O5 Total Mass: 95
# Generated Formula: C0H16O5 Total Mass: 96
# Generated Formula: C0H17O5 Total Mass: 97
# Generated Formula: C0H18O5 Total Mass: 98
# Generated Formula: C0H19O5 Total Mass: 99
# Generated Formula: C0H20O5 Total Mass: 100
# Generated Formula: C0H21O5 Total Mass: 101
# Generated Formula: C0H22O5 Total Mass: 102
# Generated Formula: C0H23O5 Total Mass: 103
# Generated Formula: C0H24O5 Total Mass: 104
# Generated Formula: C0H25O5 Total Mass: 105
# Generated Formula: C0H31O4 Total Mass: 95
# Generated Formula: C0H32O4 Total Mass: 96
# Generated Formula: C0H33O4 Total Mass: 97
# Generated Formula: C0H34O4 Total Mass: 98
# Generated Formula: C0H35O4 Total Mass: 99
# Generated Formula: C0H36O4 Total Mass: 100
# Generated Formula: C0H37O4 Total Mass: 101
# Generated Formula: C0H38O4 Total Mass: 102
# Generated Formula: C0H39O4 Total Mass: 103
 'C3H61O0', 'C3H62O0', 'C3H63O0', 'C3H64O0', 'C3H65O0', 'C3H66O0', 'C3H67O0', 'C3H68O0', 'C3H69O0', 'C4H0O3', 'C4H1O3', 'C4H2O3', 'C4H3O3', 'C4H4O3', 'C4H5O3', 'C4H6O3', 'C4H7O3', 'C4H8O3', 'C4H9O3', 'C4H15O2', 'C4H16O2', 'C4H17O2', 'C4H18O2', 'C4H19O2', 'C4H20O2', 'C4H21O2', 'C4H22O2', 'C4H23O2', 'C4H24O2', 'C4H25O2', 'C4H31O1', 'C4H32O1', 'C4H33O1', 'C4H34O1', 'C4H35O1', 'C4H36O1', 'C4H37O1', 'C4H38O1', 'C4H39O1', 'C4H40O1', 'C4H41O1', 'C4H47O0', 'C4H48O0', 'C4H49O0', 'C4H50O0', 'C4H51O0', 'C4H52O0', 'C4H53O0', 'C4H54O0', 'C4H55O0', 'C4H56O0', 'C4H57O0', 'C5H3O2', 'C5H4O2', 'C5H5O2', 'C5H6O2', 'C5H7O2', 'C5H8O2', 'C5H9O2', 'C5H10O2', 'C5H11O2', 'C5H12O2', 'C5H13O2', 'C5H19O1', 'C5H20O1', 'C5H21O1', 'C5H22O1', 'C5H23O1', 'C5H24O1', 'C5H25O1', 'C5H26O1', 'C5H27O1', 'C5H28O1', 'C5H29O1', 'C5H35O0', 'C5H36O0', 'C5H37O0', 'C5H38O0', 'C5H39O0', 'C5H40O0', 'C5H41O0', 'C5H42O0', 'C5H43O0', 'C5H44O0', 'C5H45O0', 'C6H0O2', 'C6H1O2', 'C6H7O1', 'C6H8O1', 'C6H9O1', 'C6H10O1', 'C6H11O1', 'C6H12O1', 'C6H13O1', 'C6H14O1', 'C6H15O1', 'C6H16O1', 'C6H17O1', 'C6H23O0', 'C6H24O0', 'C6H25O0', 'C6H26O0', 'C6H27O0', 'C6H28O0', 'C6H29O0', 'C6H30O0', 'C6H31O0', 'C6H32O0', 'C6H33O0', 'C7H0O1', 'C7H1O1', 'C7H2O1', 'C7H3O1', 'C7H4O1', 'C7H5O1', 'C7H11O0', 'C7H12O0', 'C7H13O0', 'C7H14O0', 'C7H15O0', 'C7H16O0', 'C7H17O0', 'C7H18O0', 'C7H19O0', 'C7H20O0 ...
# Refined Formulas After Refinement:
# C0H4O6
# C0H5O6
# C0H6O6
# C0H20O5
# C0H21O5
# C0H22O5
# C0H36O4
# C0H37O4
# C0H38O4
# C0H52O3
# C0H53O3
# C0H54O3
# C0H68O2
# C0H69O2
# C0H70O2
# C0H84O1
# C0H85O1
# C0H86O1
# C0H100O0
# C0H101O0
# C0H102O0
# C1H8O5
# C1H9O5
# C1H10O5
# C1H24O4
# C1H25O4
# C1H26O4
# C1H40O3
# C1H41O3
# C1H42O3
# C1H56O2
# C1H57O2
# C1H58O2
# C1H72O1
# C1H73O1
# C1H74O1
# C1H88O0
# C1H89O0
# C1H90O0
# C2H12O4
# C2H13O4
# C2H14O4
# C2H28O3
# C2H29O3
# C2H30O3
# C2H44O2
# C2H45O2
# C2H46O2
# C2H60O1
# C2H61O1
# C2H62O1
# C2H76O0
# C2H77O0
# C2H78O0
# C3H0O4
# C3H1O4
# C3H2O4
# C3H16O3
# C3H17O3
# C3H18O3
# C3H32O2
# C3H33O2
# C3H34O2
# C3H48O1
# C3H49O1
# C3H50O1
# C3H64O0
# C3H65O0
# C3H66O0
# C4H4O3
# C4H5O3
# C4H6O3
# C4H20O2
# C4H21O2
# C4H22O2
# C4H36O1
# C4H37O1
# C4H38O1
# C4H52O0
# C4H53O0
# C4H54O0
# C5H8O2
# C5H9O2
# C5H10O2
# C5H24O1
# C5H25O1
# C5H26O1
# C5H40O0
# C5H41O0
# C5H42O0
# C6H12O1
# C6H13O1
# C6H14O1
# C6H28O0
# C6H29O0
# C6H30O0
# C7H0O1
# C7H1O1
# C7H2O1
# C7H16O0
# C7H17O0
# C7H18O0
# C8H4O0
# C8H5O0
# C8H6O0

# %%
def calculate_formula(mass, tolerance):
    # Define atomic masses (in atomic mass units)
    atomic_masses = {'C': 12.01, 'H': 1.008, 'O': 16.00, 'N': 14.01, 'S': 32.07}

    # Define constraints on elemental ratios
    min_ratio = {'C': 0.1, 'H': 0.1, 'O': 0.0, 'N': 0.0, 'S': 0.0}  # Minimum ratio for each element
    max_ratio = {'C': 0.9, 'H': 2.0, 'O': 1.0, 'N': 0.5, 'S': 0.2}  # Maximum ratio for each element

    possible_formulas = []

    # Iterate over possible combinations of carbon, hydrogen, oxygen, nitrogen, and sulfur atoms
    for num_C in range(1, int((mass + tolerance) / atomic_masses['C']) + 1):
        for num_H in range(1, int((mass + tolerance) / atomic_masses['H']) + 1):
            for num_O in range(int((mass + tolerance) / atomic_masses['O']) + 1):
                for num_N in range(int((mass + tolerance) / atomic_masses['N']) + 1):
                    for num_S in range(int((mass + tolerance) / atomic_masses['S']) + 1):
                        # Calculate the total mass for the current combination of atoms
                        total_mass = (num_C * atomic_masses['C'] + num_H * atomic_masses['H'] +
                                      num_O * atomic_masses['O'] + num_N * atomic_masses['N'] +
                                      num_S * atomic_masses['S'])
                        # Check if the total mass is within the tolerance range
                        if abs(total_mass - mass) <= tolerance:
                            # Calculate the ratios of atoms for the current combination
                            total_atoms = num_C + num_H + num_O + num_N + num_S
                            ratio_C = num_C / total_atoms
                            ratio_H = num_H / total_atoms
                            ratio_O = num_O / total_atoms
                            ratio_N = num_N / total_atoms
                            ratio_S = num_S / total_atoms
                            # Check if the ratios satisfy the constraints
                            if (min_ratio['C'] <= ratio_C <= max_ratio['C'] and
                                min_ratio['H'] <= ratio_H <= max_ratio['H'] and
                                min_ratio['O'] <= ratio_O <= max_ratio['O'] and
                                min_ratio['N'] <= ratio_N <= max_ratio['N'] and
                                min_ratio['S'] <= ratio_S <= max_ratio['S']):
                                # If the constraints are satisfied, add the formula to the list
                                possible_formulas.append(f'C{num_C}H{num_H}O{num_O}N{num_N}S{num_S}')  # Format the formula string
    
    return possible_formulas

def refine_formulas(possible_formulas, mass_spectrum):
    # Simple refinement based on observed peaks
    refined_formulas = []
    for formula in possible_formulas:
        # Extract atomic counts from the formula
        num_C = int(formula.split('C')[1].split('H')[0].split('O')[0].split('N')[0].split('S')[0])
        num_H = int(formula.split('H')[1].split('O')[0].split('N')[0].split('S')[0])
        num_O = int(formula.split('O')[1].split('N')[0].split('S')[0])
        num_N = int(formula.split('N')[1].split('S')[0])
        num_S = int(formula.split('S')[1])
        
        # Calculate total mass of the formula
        total_mass = num_C * 12 + num_H * 1 + num_O * 16 + num_N * 14 + num_S * 32
        
        # Check if any mass in the formula is present in the mass spectrum
        if total_mass in mass_spectrum:
            refined_formulas.append(formula)
    return refined_formulas

# Example mass spectrum data (mass: intensity)
mass_spectrum = {
    100: 50,   # Peak corresponding to a compound with molecular weight 100
    101: 100,  # Isotopic peak or another compound with molecular weight 101
    102: 80,   # Peak corresponding to a compound with molecular weight 102
}

# Calculate possible formulas
possible_formulas = calculate_formula(100, 5)
print("Possible Formulas After Calculation:", possible_formulas)

# Refine formulas based on observed peaks
refined_formulas = refine_formulas(possible_formulas, mass_spectrum)

print("Refined Formulas After Refinement:")
for formula in refined_formulas:
    print(formula)
# Out:
# Possible Formulas After Calculation: ['C1H1O1N3S1', 'C1H1O2N4S0', 'C1H1O3N3S0', 'C1H2O0N4S1', 'C1H2O1N3S1', 'C1H2O2N4S0', 'C1H2O3N3S0', 'C1H3O0N4S1', 'C1H3O1N5S0', 'C1H3O2N4S0', 'C1H3O3N0S1', 'C1H3O5N0S0', 'C1H4O0N4S1', 'C1H4O3N0S1', 'C1H4O5N0S0', 'C1H5O2N1S1', 'C1H5O3N0S1', 'C1H6O0N1S2', 'C1H6O1N0S2', 'C2H1O0N3S1', 'C2H1O1N2S1', 'C2H1O1N4S0', 'C2H1O2N1S1', 'C2H1O2N3S0', 'C2H1O3N2S0', 'C2H1O4N1S0', 'C2H2O0N3S1', 'C2H2O1N2S1', 'C2H2O1N4S0', 'C2H2O2N1S1', 'C2H2O2N3S0', 'C2H2O3N2S0', 'C2H2O4N1S0', 'C2H3O0N3S1', 'C2H3O0N5S0', 'C2H3O1N2S1', 'C2H3O1N4S0', 'C2H3O2N3S0', 'C2H3O3N2S0', 'C2H4O0N3S1', 'C2H4O0N5S0', 'C2H4O1N2S1', 'C2H4O1N4S0', 'C2H4O2N3S0', 'C2H4O3N2S0', 'C2H5O0N3S1', 'C2H5O0N5S0', 'C2H5O1N4S0', 'C2H5O2N3S0', 'C2H6O0N3S1', 'C2H6O0N5S0', 'C2H6O1N4S0', 'C2H6O2N3S0', 'C2H7O0N0S2', 'C2H7O0N5S0', 'C2H7O1N4S0', 'C2H7O2N0S1', 'C2H7O4N0S0', 'C2H8O0N0S2', 'C2H8O0N5S0', 'C2H8O1N4S0', 'C2H8O2N0S1', 'C2H8O4N0S0', 'C2H9O0N0S2', 'C2H9O0N5S0', 'C2H9